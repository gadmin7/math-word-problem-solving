# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# !pip install -q --upgrade transformers datasets peft bitsandbytes trl
# !pip install -q accelerate

# %%
from accelerate.utils import write_basic_config
write_basic_config()
# Out:
# PosixPath('/root/.cache/huggingface/accelerate/default_config.yaml')

# %%
import os
import torch
import numpy as np
import pandas as pd
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    DataCollatorForLanguageModeling,
    TrainingArguments,
    AutoConfig
)
from datasets import load_dataset, concatenate_datasets
from huggingface_hub import login
from peft import LoraConfig, get_peft_model,PeftModel
from trl import SFTTrainer
import transformers
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
seed = 7
torch.manual_seed(seed)
np.random.seed(seed)

# %%
token = "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"
login(token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
save_dir = "/kaggle/working"
model_id = "meta-llama/Llama-3.2-1B-Instruct"

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_compute_dtype=torch.float16
)

# %%
lora_config = LoraConfig(
    r=32,
    lora_alpha=64,
    lora_dropout=0.2,
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj"
    ],
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id, token=token)
# Out:
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
# Define special tokens if needed
DEFAULT_PAD_TOKEN = "[PAD]"
DEFAULT_EOS_TOKEN = "</s>"
DEFAULT_BOS_TOKEN = "<s>"

special_tokens_dict = {}
if tokenizer.pad_token is None:
    special_tokens_dict['pad_token'] = DEFAULT_PAD_TOKEN
if tokenizer.eos_token is None:
    special_tokens_dict['eos_token'] = DEFAULT_EOS_TOKEN
if tokenizer.bos_token is None:
    special_tokens_dict['bos_token'] = DEFAULT_BOS_TOKEN

if special_tokens_dict:
    tokenizer.add_special_tokens(special_tokens_dict)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto",
    use_auth_token=token
)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
model.resize_token_embeddings(len(tokenizer))
model = get_peft_model(model, lora_config)
# Out:
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`

# %%
dataset = load_dataset("lighteval/MATH", trust_remote_code=True)
# Out:
# MATH.py:   0%|          | 0.00/4.10k [00:00<?, ?B/s]
# data/algebra_train.jsonl:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# (…)ata/counting_and_probability_train.jsonl:   0%|          | 0.00/707k [00:00<?, ?B/s]
# data/geometry_train.jsonl:   0%|          | 0.00/1.15M [00:00<?, ?B/s]
# data/intermediate_algebra_train.jsonl:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# data/number_theory_train.jsonl:   0%|          | 0.00/639k [00:00<?, ?B/s]
# data/prealgebra_train.jsonl:   0%|          | 0.00/778k [00:00<?, ?B/s]
# data/precalculus_train.jsonl:   0%|          | 0.00/903k [00:00<?, ?B/s]
# data/algebra_test.jsonl:   0%|          | 0.00/706k [00:00<?, ?B/s]
# data/counting_and_probability_test.jsonl:   0%|          | 0.00/377k [00:00<?, ?B/s]
# data/geometry_test.jsonl:   0%|          | 0.00/562k [00:00<?, ?B/s]
# data/intermediate_algebra_test.jsonl:   0%|          | 0.00/860k [00:00<?, ?B/s]
# data/number_theory_test.jsonl:   0%|          | 0.00/376k [00:00<?, ?B/s]
# data/prealgebra_test.jsonl:   0%|          | 0.00/553k [00:00<?, ?B/s]
# data/precalculus_test.jsonl:   0%|          | 0.00/614k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
def preprocess_function(examples):
    inputs = [
        f"<|begin_of_text|><|start_header_id|>system <|end_header_id|>"
        "You are an expert math assistant<|eot_id|><|start_header_id|>user <|end_header_id|>"
        f"Solve the following math problem: {problem}\n"
        "Show all intermediate steps and please mandatorily include the final answer in LaTeX format in a box like \\boxed{{}}."
        "<|eot_id|><|start_header_id|> assistant <|end_header_id|>"
        for problem in examples['problem']
    ]
    targets = [
        f"{solution}{tokenizer.eos_token}"
        for solution in examples['solution']
    ]
    full_texts = [inp + tgt for inp, tgt in zip(inputs, targets)]
    model_inputs = tokenizer(
        full_texts,
        max_length=512,
        truncation=True,
        padding="longest",
        return_tensors="pt"
    )
    labels = model_inputs["input_ids"].clone()

    for i in range(len(labels)):
        input_ids = tokenizer(inputs[i], add_special_tokens=False).input_ids
        input_len = len(input_ids)
        labels[i][:input_len] = -100  # Mask the input tokens
    model_inputs["labels"] = labels
    return model_inputs

# %%
tokenized_datasets = dataset.map(preprocess_function, batched=True, remove_columns=dataset['train'].column_names)
# Out:
# Map:   0%|          | 0/7500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False,  # For causal language modeling
    pad_to_multiple_of=8
)

# %%
training_args = TrainingArguments(
    output_dir="./fine_tuned_model",
    per_device_train_batch_size=4,
    gradient_accumulation_steps=2,
    warmup_ratio=0.1,
    num_train_epochs=5,
    learning_rate=5e-5,
    fp16=True,
    logging_steps=100,
    optim="paged_adamw_8bit",
    evaluation_strategy="steps",
    eval_steps=500,
    save_steps=500,
    save_total_limit=2,
    report_to="none",
    run_name="llama_finetuning_lora256",
    ddp_find_unused_parameters=False,
)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    peft_config=lora_config,
    args=training_args,
    data_collator=data_collator,
)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:309: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='4685' max='4685' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4685/4685 4:06:32, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.765000</td>
#       <td>0.770586</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.694000</td>
#       <td>0.737893</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.652300</td>
#       <td>0.723604</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.596400</td>
#       <td>0.728509</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.588400</td>
#       <td>0.720909</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.537700</td>
#       <td>0.739296</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.539200</td>
#       <td>0.736699</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.477600</td>
#       <td>0.756931</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.478800</td>
#       <td>0.757170</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# TrainOutput(global_step=4685, training_loss=0.6333007861354181, metrics={'train_runtime': 14794.9499, 'train_samples_per_second': 2.535, 'train_steps_per_second': 0.317, 'total_flos': 1.1464236991512576e+17, 'train_loss': 0.6333007861354181, 'epoch': 4.997333333333334})

# %%
model.save_pretrained("./fine_tuned_model")
tokenizer.save_pretrained("./fine_tuned_model")
# Out:
# /opt/conda/lib/python3.10/site-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# ('./fine_tuned_model/tokenizer_config.json',
#  './fine_tuned_model/special_tokens_map.json',
#  './fine_tuned_model/tokenizer.json')

# %%
print(trainer.state.log_history)
# Out:
# [{'loss': 1.6249, 'grad_norm': 0.9302037954330444, 'learning_rate': 1.0660980810234541e-05, 'epoch': 0.10666666666666667, 'step': 100}, {'loss': 0.9075, 'grad_norm': 0.9818203449249268, 'learning_rate': 2.1321961620469083e-05, 'epoch': 0.21333333333333335, 'step': 200}, {'loss': 0.8404, 'grad_norm': 1.065298318862915, 'learning_rate': 3.1982942430703626e-05, 'epoch': 0.32, 'step': 300}, {'loss': 0.7805, 'grad_norm': 0.7745354771614075, 'learning_rate': 4.2643923240938166e-05, 'epoch': 0.4266666666666667, 'step': 400}, {'loss': 0.765, 'grad_norm': 0.9336622953414917, 'learning_rate': 4.9632352941176476e-05, 'epoch': 0.5333333333333333, 'step': 500}, {'eval_loss': 0.7705860137939453, 'eval_runtime': 591.6257, 'eval_samples_per_second': 8.451, 'eval_steps_per_second': 1.056, 'epoch': 0.5333333333333333, 'step': 500}, {'loss': 0.7521, 'grad_norm': 0.8476390838623047, 'learning_rate': 4.844639468690702e-05, 'epoch': 0.64, 'step': 600}, {'loss': 0.755, 'grad_norm': 0.9653397798538208, 'learning_rate': 4.726043643263757e-05, 'epoch': 0.7466666666666667, 'step': 700}, {'loss': 0.7452, 'grad_norm': 0.8603736758232117, 'learning_rate': 4.6074478178368124e-05, 'epoch': 0.8533333333333334, 'step': 800}, {'loss': 0.7304, 'grad_norm': 0.694678783416748, 'learning_rate': 4.4888519924098676e-05, 'epoch': 0.96, 'step': 900}, {'loss': 0.694, 'grad_norm': 0.6753993034362793, 'learning_rate': 4.370256166982922e-05, 'epoch': 1.0666666666666667, 'step': 1000}, {'eval_loss': 0.7378934621810913, 'eval_runtime': 591.9479, 'eval_samples_per_second': 8.447, 'eval_steps_per_second': 1.056, 'epoch': 1.0666666666666667, 'step': 1000}, {'loss': 0.6651, 'grad_norm': 0.7341690063476562, 'learning_rate': 4.251660341555977e-05, 'epoch': 1.1733333333333333, 'step': 1100}, {'loss': 0.6884, 'grad_norm': 0.8190702199935913, 'learning_rate': 4.133064516129033e-05, 'epoch': 1.28, 'step': 1200}, {'loss': 0.6756, 'grad_norm': 1.204841136932373, 'learning_rate': 4.0144686907020875e-05, 'epoch': 1.3866666666666667, 'step': 1300}, {'loss': 0.6681, 'grad_norm': 0.7314171195030212, 'learning_rate': 3.8958728652751426e-05, 'epoch': 1.4933333333333334, 'step': 1400}, {'loss': 0.6523, 'grad_norm': 0.7558402419090271, 'learning_rate': 3.777277039848198e-05, 'epoch': 1.6, 'step': 1500}, {'eval_loss': 0.7236040830612183, 'eval_runtime': 592.2064, 'eval_samples_per_second': 8.443, 'eval_steps_per_second': 1.055, 'epoch': 1.6, 'step': 1500}, {'loss': 0.6658, 'grad_norm': 0.7682256102561951, 'learning_rate': 3.658681214421252e-05, 'epoch': 1.7066666666666666, 'step': 1600}, {'loss': 0.6685, 'grad_norm': 0.8431659936904907, 'learning_rate': 3.5400853889943074e-05, 'epoch': 1.8133333333333335, 'step': 1700}, {'loss': 0.6784, 'grad_norm': 1.0103790760040283, 'learning_rate': 3.4214895635673625e-05, 'epoch': 1.92, 'step': 1800}, {'loss': 0.6581, 'grad_norm': 0.7603870034217834, 'learning_rate': 3.302893738140418e-05, 'epoch': 2.026666666666667, 'step': 1900}, {'loss': 0.5964, 'grad_norm': 0.9397332668304443, 'learning_rate': 3.184297912713473e-05, 'epoch': 2.1333333333333333, 'step': 2000}, {'eval_loss': 0.7285094261169434, 'eval_runtime': 594.1457, 'eval_samples_per_second': 8.415, 'eval_steps_per_second': 1.052, 'epoch': 2.1333333333333333, 'step': 2000}, {'loss': 0.5991, 'grad_norm': 1.098947525024414, 'learning_rate': 3.065702087286528e-05, 'epoch': 2.24, 'step': 2100}, {'loss': 0.6041, 'grad_norm': 0.9707804322242737, 'learning_rate': 2.9471062618595828e-05, 'epoch': 2.3466666666666667, 'step': 2200}, {'loss': 0.5976, 'grad_norm': 1.3444198369979858, 'learning_rate': 2.8285104364326376e-05, 'epoch': 2.453333333333333, 'step': 2300}, {'loss': 0.6039, 'grad_norm': 1.0324203968048096, 'learning_rate': 2.7099146110056927e-05, 'epoch': 2.56, 'step': 2400}, {'loss': 0.5884, 'grad_norm': 1.045697569847107, 'learning_rate': 2.591318785578748e-05, 'epoch': 2.6666666666666665, 'step': 2500}, {'eval_loss': 0.7209087610244751, 'eval_runtime': 594.332, 'eval_samples_per_second': 8.413, 'eval_st ...

# %%
model.eval()  # Set model to evaluation mode

test_samples = []
for idx in range(len(dataset['test'])):
    sample = dataset['test'][idx]
    input_text = (
        f"<|begin_of_text|><|start_header_id|>system <|end_header_id|>"
        "You are an expert math assistant<|eot_id|><|start_header_id|>user <|end_header_id|>"
        f"Solve the following math problem: {sample['problem']}\n"
        "Show all intermediate steps and please mandatorily include the final answer in LaTeX format in a box like \\boxed{{}}."
        "<|eot_id|><|start_header_id|> assistant <|end_header_id|>"
    )
    test_samples.append({
        "input_text": input_text,
        "problem": sample['problem'],
        "level": sample['level'],
        "type": sample['type'],
        "ground_truth": sample['solution']
    })
    
def collate_fn(batch):
    input_texts = [sample['input_text'] for sample in batch]
    model_inputs = tokenizer(
        input_texts,
        padding=True,
        truncation=True,
        max_length=1024,  # Adjust as needed
        return_tensors="pt"
    )
    model_inputs = {k: v.to(model.device) for k, v in model_inputs.items()}
    return model_inputs, batch

batch_size = 32  # Adjust based on your GPU memory
test_dataloader = DataLoader(test_samples, batch_size=batch_size, collate_fn=collate_fn)

results_list = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for batch_idx, (model_inputs, batch_samples) in enumerate(tqdm(test_dataloader, desc=f"Evaluating")):
    current_batch_size = model_inputs['input_ids'].size(0)
    # Generate predictions
    try:
        with torch.no_grad():
            output_ids = model.generate(
                input_ids=model_inputs['input_ids'],
                attention_mask=model_inputs['attention_mask'],
                max_new_tokens=512,  
                do_sample=False,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.pad_token_id
            )
        # Decode the outputs
        for i in range(current_batch_size):
            predicted_text = tokenizer.decode(output_ids[i], skip_special_tokens=True)
            # Store the results
            results_list.append({
                "problem": batch_samples[i]['problem'],
                "level": batch_samples[i]['level'],
                "type": batch_samples[i]['type'],
                "ground_truth": batch_samples[i]['ground_truth'],
                "predicted_solution": predicted_text
            })
    except Exception as e:
        print(f"Error during generation at batch {batch_idx+1}: {e}")
        # In case of error, record empty predictions for this batch
        for i in range(current_batch_size):
            results_list.append({
                "problem": batch_samples[i]['problem'],
                "level": batch_samples[i]['level'],
                "type": batch_samples[i]['type'],
                "ground_truth": batch_samples[i]['ground_truth'],
                "predicted_solution": ""  # Empty string for predicted_text
            })
        continue  # Proceed to the next batch

    # Optionally, save intermediate results every N batches
    if (batch_idx + 1) % 100 == 0:
        results_df = pd.DataFrame(results_list)
        results_save_path = os.path.join(save_dir, f"test_results_batch_{batch_idx+1}.csv")
        results_df.to_csv(results_save_path, index=False)
        print(f"Saved test results up to batch {batch_idx+1} to {results_save_path}")


results_df = pd.DataFrame(results_list)
results_save_path = os.path.join(save_dir, f"test_results_overall.csv")
results_df.to_csv(results_save_path, index=False)
print(f"Saved test results to {results_save_path}")
# Out:
# Evaluating:   0%|          | 0/157 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:595: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   1%|          | 1/157 [00:48<2:05:37, 48.32s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   1%|▏         | 2/157 [01:41<2:11:43, 50.99s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 3/157 [02:28<2:06:17, 49.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 4/157 [03:21<2:09:20, 50.72s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 5/157 [03:56<1:54:36, 45.24s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   4%|▍         | 6/157 [04:46<1:57:33, 46.71s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   4%|▍         | 7/157 [05:28<1:53:24, 45.36s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 8/157 [06:12<1:50:48, 44.62s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   6%|▌         | 9/157 [06:54<1:48:36, 44.03s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   6%|▋         | 10/157 [07:37<1:47:16, 43.79s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 11/157 [08:16<1:42:37, 42.17s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 12/157 [09:01<1:43:58, 43.02s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 13/157 [09:24<1:28:38, 36.93s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   9%|▉         | 14/157 [10:07<1:32:47, 38.94s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|▉         | 15/157 [11:05<1:45:45, 44.69s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 16/157 [11:48<1:43:48, 44.17s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  11%|█         | 17/157 [12:33<1:43:34, 44.39s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  11%|█▏        | 18/157 [13:16<1:41:52, 43.97s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 19/157 [14:25<1:58:22, 51.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 20/157 [15:08<1:51:33, 48.86s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 21/157 [15:51<1:46:29, 46.98s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  14%|█▍        | 22/157 [16:40<1:47:09, 47.63s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▍        | 23/157 [17:33<1:49:51, 49.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 24/157 [18:16<1:45:07, 47.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  16%|█▌        | 25/157 [19:13<1:50:46, 50.35s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 26/157 [19:56<1:45:19, 48.24s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 27/157 [20:41<1:42:02, 47.09s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 28/157 [21:24<1:38:37, 45.87s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 29/157 [22:08<1:36:26, 45.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  19%|█▉        | 30/157 [22:58<1:39:13, 46.88s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|█▉        | 31/157 [23:42<1:36:39, 46.03s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 32/157 [24:25<1:33:55, 45.09s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  21%|██        | 33/157 [25:09<1:32:12, 44.62s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 34/157 [25:43<1:25:19, 41.62s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 35/157 [26:26<1:25:31, 42.06s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 36/157 [27:10<1:25:30, 42.40s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  24%|██▎       | 37/157 [27:57<1:27:37, 43.81s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating: